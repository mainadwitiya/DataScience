# %% [markdown]
# <a href="https://colab.research.google.com/github/mainadwitiya/DataScience/blob/master/datetimeplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install collections-extended
# !pip install datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
from matplotlib import dates as mpl_dates
from datetime import datetime,timedelta

# %%
plt.style.use('seaborn')
dates=[datetime(2020,1,23),
       datetime(2020,1,24),
       datetime(2020,1,25),
       datetime(2020,1,26),
       datetime(2020,1,26),
       datetime(2020,1,28),
       datetime(2020,1,29)]
y=[0,1,2,3,4,5,6]

plt.plot_date(dates,y,linestyle='solid')
#get current figure
plt.gcf().autofmt_xdate
#FORMATTING DATES

date_format=mpl_dates.DateFormatter('%b,%d %Y')
plt.gca().xaxis.set_major_formatter(date_format)

# %%
from google.colab import files
uploaded=files.upload()
df=pd.read_csv(io.BytesIO(uploaded['datesdata.csv']))
# Out:
#      <input type="file" id="files-b34e8c18-f71f-478c-9041-0a55044a84b6" name="files[]" multiple disabled />
#      <output id="result-b34e8c18-f71f-478c-9041-0a55044a84b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datesdata.csv to datesdata.csv

# %%
#NOTE HERE DATES CAN BE OUT OF ORDER SO WE MUST SORT ACCORDING TO THE DATE
df['Date']=pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
price_date=df['Date']
price_close=df['Close']
plt.plot_date(price_date,price_close,linestyle='solid')
#THIS IS DATE TIME FORMATTER
date_format=mpl_dates.DateFormatter('%b, %d %Y')
plt.gca().xaxis.set_major_formatter(date_format)
