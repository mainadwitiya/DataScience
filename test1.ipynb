# %% [markdown]
# <a href="https://colab.research.google.com/github/mainadwitiya/DataScience/blob/master/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install collections-extended
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
from collections import Counter
from google.colab import files
uploaded=files.upload()
# Out:
# ...
#      <input type="file" id="files-e08a555f-83b4-4174-84fb-b9ee197220d7" name="files[]" multiple disabled />
#      <output id="result-e08a555f-83b4-4174-84fb-b9ee197220d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data (1).csv

# %%
# !pip install items
import items
df2 = pd.read_csv(io.BytesIO(uploaded['data.csv']))
language_counter=Counter()
ids=df2['Responder_id']
lang_responses=df2['LanguagesWorkedWith']
for response in lang_responses:
  language_counter.update(response.split(';'))

#print(language_counter.most_common(15))
languages=[]
popularity=[]
for item in language_counter.most_common(15):
  languages.append(item[0])
  popularity.append(item[1])  
plt.style.use('seaborn')
#For popular languages 1st do
#language.reverse()
#popularity.reverse()
#use barh for horizontal
plt.barh(languages,popularity)
plt.title('Most popular Languages')
plt.ylabel('Language')
plt.xlabel('Number of people')
plt.tight_layout()
plt.show()
