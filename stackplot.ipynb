# %% [markdown]
# <a href="https://colab.research.google.com/github/mainadwitiya/DataScience/blob/master/stackplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
#plt.style.use('seaborn')

minutes=[1,2,3,4,5,6,7,8,9]
player1=[1,2,3,3,4,4,4,4,5]
player2=[1,1,1,1,2,2,2,3,4]
player3=[1,1,1,1,2,2,3,3,3]
#to move the legend towards left or right put loc
colors=['#f6498d','#b1e7f4','#ffe667']
plt.stackplot(minutes,player1,player2,player3,labels=labels,colors=colors)

labels=['player1','player2','player3']
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
